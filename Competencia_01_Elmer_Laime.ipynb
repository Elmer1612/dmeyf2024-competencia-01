# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = "/content/drive/MyDrive/1- DM en Economía y Finanzas - Lunes y Jueves/Clase ternaria"

# %%
df = pd.read_csv(f"{DIR}/competencia_01_crudo.csv")

# %%
df.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221109    202101               1            0         0
# 1          249221468    202101               1            0         0
# 2          249223005    202101               1            0         0
# 3          249228180    202101               1            0         0
# 4          249232117    202101               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 300        1664.94              17994.40
# 1            53                  37        4879.78              18640.95
# 2            48                 202        1828.35              37789.01
# 3            66                 320         175.87               2600.67
# 4            79                 373       16600.69              32270.07
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      1605.81  ...                    0.0                  4.0           0.0
# 1      1149.08  ...                    0.0                  4.0           0.0
# 2       610.12  ...                    0.0                  4.0           0.0
# 3       276.22  ...                    0.0                  4.0           0.0
# 4     16367.13  ...                    0.0                  4.0           0.0
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0         -37098.90                 0.0          7867.0           118514.88
# 1          -9864.93                 0.0          1124.0            31427.14
# 2         -32119.08                 0.0          3486.0              855.11
# 3         -10891.30                 0.0          8925.0             7517.73
# 4         -43610.75                 0.0          8607.0            37309.25
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0            10.0                      0.0          76538.25
# 1            14.0                      0.0              0.00
# 2             2.0                      0.0          19389.69
# 3             6.0                      0.0            516.12
# 4             5.0                      0.0           3084.99
#
# [5 rows x 154 columns]

# %% [markdown]
# c. Ordeno el DataFrame y reseteo el índice.

# %%
df = df.sort_values(by=["numero_de_cliente", "foto_mes"], ascending=True)
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221109    202101               1            0         0
# 1          249221109    202102               1            0         0
# 2          249221109    202103               1            0         0
# 3          249221109    202104               1            0         0
# 4          249221109    202105               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 300        1664.94              17994.40
# 1            61                 301        1002.92              18337.34
# 2            61                 302         769.74              18596.58
# 3            62                 303        1532.79              19935.00
# 4            62                 304        1804.14              20862.15
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      1605.81  ...                    0.0                  4.0           0.0
# 1      1312.91  ...                    0.0                 -3.0           0.0
# 2      1662.56  ...                    0.0                  1.0           0.0
# 3      1899.52  ...                    0.0                  2.0           0.0
# 4      2693.91  ...                    0.0                  5.0           0.0
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0         -37098.90                0.00          7867.0           118514.88
# 1        -126627.68             1219.19          7895.0            28941.76
# 2         -31388.56                0.00          7926.0             9564.73
# 3         -11773.53                0.00          7956.0            18078.27
# 4         -19480.30                0.00          7987.0            20336.57
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0            10.0                      0.0          76538.25
# 1            13.0                      0.0           2545.41
# 2             9.0                      0.0           1536.63
# 3            10.0                      0.0           1067.43
# 4             9.0                      0.0            199.41
#
# [5 rows x 154 columns]

# %% [markdown]
# d. Genero una copia para trabajarla con la clase ternaria.

# %%
df_clase = df.copy()

# %% [markdown]
# e. Filtro las columnas de interés.

# %%
df_clase = df_clase[["numero_de_cliente", "foto_mes"]]

# %% [markdown]
# f. Creo una columna para contar el orden de aparición del mes por cliente

# %%
df_clase["Acumulado"] = 1
df_clase["Acumulado"] = df_clase.groupby("numero_de_cliente").cumsum()["Acumulado"]

# %% [markdown]
# i. Creo la columna propiamente dicha.

# %%
df_clase["CLASE_TERNARIA"] = None

# %%
for indice in range(len(df_clase)):
    #1. Verifico el mes de evaluación (para no evaluar meses posteriores a abril de 2021).
    if df_clase.iloc[indice]["foto_mes"] <= 202104:
        #A. Creo condiciones de evaluación.
        verific_sig_mes = (df_clase.iloc[indice + 1]["Acumulado"] == df_clase.iloc[indice]["Acumulado"] + 1)
        verific_sig_dos_meses = (df_clase.iloc[indice + 2]["Acumulado"] == df_clase.iloc[indice]["Acumulado"] + 2)
        #B. Evaluo dichas condiciones.
        if not verific_sig_mes:
            df_clase.loc[indice, "CLASE_TERNARIA"] = "BAJA+1"
        elif verific_sig_mes and not verific_sig_dos_meses:
            df_clase.loc[indice, "CLASE_TERNARIA"] = "BAJA+2"
        elif verific_sig_mes and verific_sig_dos_meses:
            df_clase.loc[indice, "CLASE_TERNARIA"] = "CONTINUA"
        else:
            df_clase.loc[indice, "CLASE_TERNARIA"] = "Error"
    else:
        df_clase.loc[indice, "CLASE_TERNARIA"] = None
    #2. Imprimo por qué número de fila está el proceso.
    if indice % 100000 == 0:
        print(indice)
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000

# %% [markdown]
# h. Me quedo con la columna de interés, y la mergeo al DataFrame original.

# %%
df["CLASE_TERNARIA"] = df_clase["CLASE_TERNARIA"]

# %%
df.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221109    202101               1            0         0
# 1          249221109    202102               1            0         0
# 2          249221109    202103               1            0         0
# 3          249221109    202104               1            0         0
# 4          249221109    202105               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 300        1664.94              17994.40
# 1            61                 301        1002.92              18337.34
# 2            61                 302         769.74              18596.58
# 3            62                 303        1532.79              19935.00
# 4            62                 304        1804.14              20862.15
#
#    mcomisiones  ...  Visa_fultimo_cierre  Visa_mpagado  Visa_mpagospesos  \
# 0      1605.81  ...                  4.0           0.0         -37098.90
# 1      1312.91  ...                 -3.0           0.0        -126627.68
# 2      1662.56  ...                  1.0           0.0         -31388.56
# 3      1899.52  ...                  2.0           0.0         -11773.53
# 4      2693.91  ...                  5.0           0.0         -19480.30
#
#    Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  Visa_cconsumos  \
# 0                0.00          7867.0           118514.88            10.0
# 1             1219.19          7895.0            28941.76            13.0
# 2                0.00          7926.0             9564.73             9.0
# 3                0.00          7956.0            18078.27            10.0
# 4                0.00          7987.0            20336.57             9.0
#
#    Visa_cadelantosefectivo  Visa_mpagominimo  CLASE_TERNARIA
# 0                      0.0          76538.25        CONTINUA
# 1                      0.0           2545.41        CONTINUA
# 2                      0.0           1536.63        CONTINUA
# 3                      0.0           1067.43        CONTINUA
# 4                      0.0            199.41            None
#
# [5 rows x 155 columns]

# %% [markdown]
# # i. Guardo el DataFrame actualizado en un nuevo archivo CSV

# %%
# i. Guardo el DataFrame actualizado en el archivo CSV en la dirección especificada
DIR = "/content/drive/MyDrive/1- DM en Economía y Finanzas - Lunes y Jueves/Clase ternaria"
df.to_csv(f"{DIR}/competencia_01_con_clase_ternaria.csv", index=False)

print("Archivo CSV guardado exitosamente en la dirección especificada.")
# Out:
# Archivo CSV guardado exitosamente en la dirección especificada.

# %% [markdown]
# # Cargo el DataFrame actualizado en un nuevo archivo CSV

# %%
# Importar las librerías necesarias
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import os

# %%
# Leer el dataset
dataset = pd.read_csv('/content/drive/My Drive/1- DM en Economía y Finanzas - Lunes y Jueves/Clase ternaria/competencia_01_con_clase_ternaria.csv')

# %%
dataset.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221109    202101               1            0         0
# 1          249221109    202102               1            0         0
# 2          249221109    202103               1            0         0
# 3          249221109    202104               1            0         0
# 4          249221109    202105               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 300        1664.94              17994.40
# 1            61                 301        1002.92              18337.34
# 2            61                 302         769.74              18596.58
# 3            62                 303        1532.79              19935.00
# 4            62                 304        1804.14              20862.15
#
#    mcomisiones  ...  Visa_fultimo_cierre  Visa_mpagado  Visa_mpagospesos  \
# 0      1605.81  ...                  4.0           0.0         -37098.90
# 1      1312.91  ...                 -3.0           0.0        -126627.68
# 2      1662.56  ...                  1.0           0.0         -31388.56
# 3      1899.52  ...                  2.0           0.0         -11773.53
# 4      2693.91  ...                  5.0           0.0         -19480.30
#
#    Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  Visa_cconsumos  \
# 0                0.00          7867.0           118514.88            10.0
# 1             1219.19          7895.0            28941.76            13.0
# 2                0.00          7926.0             9564.73             9.0
# 3                0.00          7956.0            18078.27            10.0
# 4                0.00          7987.0            20336.57             9.0
#
#    Visa_cadelantosefectivo  Visa_mpagominimo  CLASE_TERNARIA
# 0                      0.0          76538.25        CONTINUA
# 1                      0.0           2545.41        CONTINUA
# 2                      0.0           1536.63        CONTINUA
# 3                      0.0           1067.43        CONTINUA
# 4                      0.0            199.41             NaN
#
# [5 rows x 155 columns]

# %%
dataset.shape
# Out:
# (981946, 155)
